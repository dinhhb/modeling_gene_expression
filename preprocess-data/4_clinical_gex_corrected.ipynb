# %% [markdown]
# # Merge Clinical + corrected GEX data

# %%
import pandas as pd

# %%
gex_mat = pd.read_csv(f"../dataset/created/gex_mat_corrected_sig.csv").set_index('sample_id').T
gex_mat['sample_id'] = gex_mat.index
gex_mat
# Out:
# sample_id        MAGEA4    MAGEA1     VCX3A      SV2B  BAIAP2L1      VCX2  \
# 03660555B      4.298675  5.143281  5.096021  4.656211  5.647183  5.262724
# 03660598B      6.516769  5.390489  5.117279  4.668190  5.775339  5.241646
# 03660602B      5.067833  4.897864  5.565421  4.650660  5.590498  5.246197
# 04240076F      4.276826  4.498819  5.081262  4.677048  5.721581  5.234033
# 04240106F      4.276790  4.820164  5.092965  4.716673  5.731831  5.238127
# ...                 ...       ...       ...       ...       ...       ...
# Pt4-baseline   7.050444  5.983532  5.530442  4.916466  5.182387  5.660418
# Pt10-baseline  4.748696  5.011822  5.538210  4.912395  5.355619  5.668210
# Pt16-baseline  4.632310  4.787164  5.529004  4.911302  5.163784  5.660418
# Pt17-baseline  4.634702  4.776978  5.529004  5.043438  5.059882  5.660418
# Pt6-baseline   4.632310  4.845365  5.529004  4.898404  5.564387  5.660418
#
# sample_id        CKMT1A   MAGEA10     CTAG2      GNB5  ...    MAGEA3  \
# 03660555B      4.878165  4.596075  4.635997  5.528943  ...  6.284474
# 03660598B      4.863413  4.612415  4.630064  5.537698  ...  6.862708
# 03660602B      4.862598  4.543948  4.630064  5.665834  ...  5.626812
# 04240076F      4.864543  4.539119  4.640348  5.534643  ...  4.948698
# 04240106F      4.861666  4.827292  4.630064  5.393001  ...  6.264354
# ...                 ...       ...       ...       ...  ...       ...
# Pt4-baseline   4.658897  5.442767  6.225325  5.544884  ...  5.594205
# Pt10-baseline  5.946365  5.171245  4.200019  5.462456  ...  5.748913
# Pt16-baseline  5.393081  4.834914  7.036676  5.841635  ...  6.238433
# Pt17-baseline  4.345292  4.834914  4.128368  5.820427  ...  5.333456
# Pt6-baseline   4.353053  4.834914  4.771073  5.457626  ...  6.507692
#
# sample_id      TNFAIP8L2   HERC2P4     PNMA2   SLC28A3      ALAD      RHCE  \
# 03660555B       4.297704  4.262785  5.274553  3.888714  5.890571  4.040785
# 03660598B       4.276909  4.483725  5.299898  3.846581  6.463356  4.002404
# 03660602B       4.337528  4.258745  5.309691  3.851291  5.914027  4.059241
# 04240076F       4.413269  4.219724  5.321396  3.871215  5.981546  4.049749
# 04240106F       4.295142  4.685055  5.301190  3.859265  6.369937  4.339283
# ...                  ...       ...       ...       ...       ...       ...
# Pt4-baseline    4.584799  4.459048  4.900091  4.007242  5.833042  4.025481
# Pt10-baseline   4.317679  4.454954  5.023566  4.049761  6.137828  4.035033
# Pt16-baseline   4.345152  4.450419  5.334232  3.975395  6.391950  4.049596
# Pt17-baseline   5.124939  4.451894  5.356338  4.047086  6.012168  4.011786
# Pt6-baseline    4.214394  4.450419  4.893445  3.976408  5.385450  4.038785
#
# sample_id         SORL1    SAMD4A      sample_id
# 03660555B      5.674289  5.297394      03660555B
# 03660598B      5.224376  5.490748      03660598B
# 03660602B      6.147752  5.007887      03660602B
# 04240076F      5.336090  5.050745      04240076F
# 04240106F      6.487131  5.317965      04240106F
# ...                 ...       ...            ...
# Pt4-baseline   6.240612  4.880488   Pt4-baseline
# Pt10-baseline  5.673329  4.936892  Pt10-baseline
# Pt16-baseline  5.553562  5.072633  Pt16-baseline
# Pt17-baseline  5.556268  4.905885  Pt17-baseline
# Pt6-baseline   5.857508  4.917957   Pt6-baseline
#
# [134 rows x 158 columns]

# %%
clinical_gex = pd.read_csv(f"../dataset/created/clinical_gex.csv", index_col='Unnamed: 0')
clinical_gex
# Out:
# /var/folders/cy/vstztct90b90zhd8ssbmwpgh0000gn/T/ipykernel_14558/1644580541.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   clinical_gex = pd.read_csv(f"../dataset/created/clinical_gex.csv", index_col='Unnamed: 0')
#      patientID     sex  age AJCC_stage M_stage       LDH  \
# 0      YR_3053    male   26         IV     M1B  elevated
# 1      YR_3708  female   58         IV     M1A    normal
# 2      YR_3705    male   45         IV     M1A    normal
# 3      YR_1106    male   48       IIIC     NaN    normal
# 4      YR_1110    male   33         IV     M1C    normal
# ..         ...     ...  ...        ...     ...       ...
# 129  HL_Shi-35    male   61         IV     M1C       NaN
# 130  HL_Shi-37    male   65         IV     M1A       NaN
# 131  HL_Shi-38    male   51         IV     M1C       NaN
# 132  HL_Shi-43  female   41         IV     M1C       NaN
# 133  HL_Shi-44    male   83         IV     M1C       NaN
#
#     immunotherapy_treatment pre_MAPKi_treatment       source  pfs_label  ...  \
# 0                        no                  no   Yan et al.          0  ...
# 1                        no                  no   Yan et al.          2  ...
# 2                        no                  no   Yan et al.          2  ...
# 3                        no                  no   Yan et al.          0  ...
# 4                        no                  no   Yan et al.          0  ...
# ..                      ...                 ...          ...        ...  ...
# 129                      no                  no  Hugo et al.          1  ...
# 130                      no                  no  Hugo et al.          2  ...
# 131                      no                  no  Hugo et al.          0  ...
# 132                      no                  no  Hugo et al.          1  ...
# 133                      no                  no  Hugo et al.          0  ...
#
#      sept-05  sept-06  sept-07  sept-08  sept-09  sept-10  sept-11  sept-12  \
# 0        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 129      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 130      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 131      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 132      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 133      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#      sept-14  sept-15
# 0        NaN      NaN
# 1        NaN      NaN
# 2        NaN      NaN
# 3        NaN      NaN
# 4        NaN      NaN
# ..       ...      ...
# 129      NaN      NaN
# 130      NaN      NaN
# 131      NaN      NaN
# 132      NaN      NaN
# 133      NaN      NaN
#
# [134 rows x 51486 columns]

# %%
CLINICAL_COLS = ["patientID", "sex", "age", "AJCC_stage", "M_stage", "LDH", 'sample_id', 'pfs_label',
                "immunotherapy_treatment", "pre_MAPKi_treatment",
                "source", "cobimetinib", "dabrafenib", "trametinib","vemurafenib", 
                "C195W", "K601I", "MND", "V600E", "V600K","V600R"]
GEX_COLS = [c for c in clinical_gex.columns if c not in CLINICAL_COLS]

clinical_gex = clinical_gex[CLINICAL_COLS]

# %%
gex_mat_reset = gex_mat.reset_index()
clinical_gex_1 = clinical_gex.merge(gex_mat_reset, on='sample_id', how='inner')

clinical_gex_1
# Out:
#      patientID     sex  age AJCC_stage M_stage       LDH      sample_id  \
# 0      YR_3053    male   26         IV     M1B  elevated      03660555B
# 1      YR_3708  female   58         IV     M1A    normal      03660598B
# 2      YR_3705    male   45         IV     M1A    normal      03660602B
# 3      YR_1106    male   48       IIIC     NaN    normal      04240076F
# 4      YR_1110    male   33         IV     M1C    normal      04240106F
# ..         ...     ...  ...        ...     ...       ...            ...
# 129  HL_Shi-35    male   61         IV     M1C       NaN   Pt4-baseline
# 130  HL_Shi-37    male   65         IV     M1A       NaN  Pt10-baseline
# 131  HL_Shi-38    male   51         IV     M1C       NaN  Pt16-baseline
# 132  HL_Shi-43  female   41         IV     M1C       NaN  Pt17-baseline
# 133  HL_Shi-44    male   83         IV     M1C       NaN   Pt6-baseline
#
#      pfs_label immunotherapy_treatment pre_MAPKi_treatment  ...   SLC6A20  \
# 0            0                      no                  no  ...  4.384223
# 1            2                      no                  no  ...  4.385748
# 2            2                      no                  no  ...  4.384223
# 3            0                      no                  no  ...  4.385166
# 4            0                      no                  no  ...  4.385145
# ..         ...                     ...                 ...  ...       ...
# 129          1                      no                  no  ...  4.346945
# 130          2                      no                  no  ...  4.355378
# 131          0                      no                  no  ...  4.350000
# 132          1                      no                  no  ...  4.345396
# 133          0                      no                  no  ...  4.345965
#
#        MAGEA3  TNFAIP8L2   HERC2P4     PNMA2   SLC28A3      ALAD      RHCE  \
# 0    6.284474   4.297704  4.262785  5.274553  3.888714  5.890571  4.040785
# 1    6.862708   4.276909  4.483725  5.299898  3.846581  6.463356  4.002404
# 2    5.626812   4.337528  4.258745  5.309691  3.851291  5.914027  4.059241
# 3    4.948698   4.413269  4.219724  5.321396  3.871215  5.981546  4.049749
# 4    6.264354   4.295142  4.685055  5.301190  3.859265  6.369937  4.339283
# ..        ...        ...       ...       ...       ...       ...       ...
# 129  5.594205   4.584799  4.459048  4.900091  4.007242  5.833042  4.025481
# 130  5.748913   4.317679  4.454954  5.023566  4.049761  6.137828  4.035033
# 131  6.238433   4.345152  4.450419  5.334232  3.975395  6.391950  4.049596
# 132  5.333456   5.124939  4.451894  5.356338  4.047086  6.012168  4.011786
# 133  6.507692   4.214394  4.450419  4.893445  3.976408  5.385450  4.038785
#
#         SORL1    SAMD4A
# 0    5.674289  5.297394
# 1    5.224376  5.490748
# 2    6.147752  5.007887
# 3    5.336090  5.050745
# 4    6.487131  5.317965
# ..        ...       ...
# 129  6.240612  4.880488
# 130  5.673329  4.936892
# 131  5.553562  5.072633
# 132  5.556268  4.905885
# 133  5.857508  4.917957
#
# [134 rows x 179 columns]

# %%
clinical_gex_1.to_csv(f"../dataset/created/clinical_gex_corrected.csv", index=False)
