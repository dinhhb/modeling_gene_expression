# %% [markdown]
# ## Gene Expression (GEx)

# %%
import polars as pl

# %%
gex_df = pl.read_csv("../dataset/created/gex_rna_seq.csv")
gex_df
# Out:
# shape: (2_671_394, 5)
# ┌───────────┬───────────────┬─────────┬───────────┬─────────────┐
# │ patientID ┆ sample_id     ┆ HGNC    ┆ value     ┆ source      │
# │ ---       ┆ ---           ┆ ---     ┆ ---       ┆ ---         │
# │ str       ┆ str           ┆ str     ┆ f64       ┆ str         │
# ╞═══════════╪═══════════════╪═════════╪═══════════╪═════════════╡
# │ YR_5306   ┆ 03660445B     ┆ NAT2    ┆ 0.0       ┆ Yan et al.  │
# │ YR_5306   ┆ 03660445B     ┆ ADA     ┆ 26.233973 ┆ Yan et al.  │
# │ YR_5306   ┆ 03660445B     ┆ CDH2    ┆ 1.138609  ┆ Yan et al.  │
# │ YR_5306   ┆ 03660445B     ┆ AKT3    ┆ 12.692677 ┆ Yan et al.  │
# │ YR_5306   ┆ 03660445B     ┆ GAGE12F ┆ 0.0       ┆ Yan et al.  │
# │ …         ┆ …             ┆ …       ┆ …         ┆ …           │
# │ HL_Shi-43 ┆ Pt17-baseline ┆ ZYG11A  ┆ 0.0625681 ┆ Hugo et al. │
# │ HL_Shi-43 ┆ Pt17-baseline ┆ ZYG11B  ┆ 5.74608   ┆ Hugo et al. │
# │ HL_Shi-43 ┆ Pt17-baseline ┆ ZYX     ┆ 45.907933 ┆ Hugo et al. │
# │ HL_Shi-43 ┆ Pt17-baseline ┆ ZZEF1   ┆ 3.015137  ┆ Hugo et al. │
# │ HL_Shi-43 ┆ Pt17-baseline ┆ ZZZ3    ┆ 10.684633 ┆ Hugo et al. │
# └───────────┴───────────────┴─────────┴───────────┴─────────────┘

# %%
dupes = gex_df.to_pandas().duplicated(subset=['HGNC', 'sample_id'], keep=False)
print(gex_df.to_pandas()[dupes])
# Out:
#         patientID sample_id                     HGNC   value        source
# 1921836     KC_10       10A                      AK2  113.26  Kwong et al.
# 1921854     KC_10       10A                    CDC27   12.46  Kwong et al.
# 1921942     KC_10       10A                     SCIN    0.60  Kwong et al.
# 1922048     KC_10       10A                      IDS   17.56  Kwong et al.
# 1922147     KC_10       10A  RGPD4 (includes others)    0.82  Kwong et al.
# ...           ...       ...                      ...     ...           ...
# 2368161      KC_9        9A                 mir-4444    0.00  Kwong et al.
# 2368166      KC_9        9A                  mir-548    0.00  Kwong et al.
# 2368167      KC_9        9A                  mir-548    0.00  Kwong et al.
# 2368168      KC_9        9A                 mir-3689    0.00  Kwong et al.
# 2368169      KC_9        9A                     PPY2    0.00  Kwong et al.
#
# [21042 rows x 5 columns]

# %%
print(f"Shape before deduplication: {gex_df.shape}")
# Out:
# Shape before deduplication: (2671394, 5)

# %%
# For duplicate (HGNC, sample_id) pairs, keep the one with the max value
gex_df = gex_df.sort('value', descending=True).unique(subset=['HGNC', 'sample_id'], keep='first')
print(f"Shape after deduplication: {gex_df.shape}")
# Out:
# Shape after deduplication: (2658458, 5)

# %%
dupes = gex_df.to_pandas().duplicated(subset=['HGNC', 'sample_id'], keep=False)
print(gex_df.to_pandas()[dupes])
# Out:
# Empty DataFrame
# Columns: [patientID, sample_id, HGNC, value, source]
# Index: []

# %%
gex_df
# Out:
# shape: (2_658_458, 5)
# ┌───────────┬──────────────┬───────────┬───────────┬──────────────┐
# │ patientID ┆ sample_id    ┆ HGNC      ┆ value     ┆ source       │
# │ ---       ┆ ---          ┆ ---       ┆ ---       ┆ ---          │
# │ str       ┆ str          ┆ str       ┆ f64       ┆ str          │
# ╞═══════════╪══════════════╪═══════════╪═══════════╪══════════════╡
# │ YR_2417   ┆ 05320459B    ┆ CYP4F24P  ┆ 0.050866  ┆ Yan et al.   │
# │ YR_2035   ┆ 05320196B    ┆ TEX11     ┆ 0.029169  ┆ Yan et al.   │
# │ YR_2174   ┆ 05320234B    ┆ TBC1D9B   ┆ 18.593042 ┆ Yan et al.   │
# │ YR_1106   ┆ 04240076F    ┆ PMCHL2    ┆ 0.0       ┆ Yan et al.   │
# │ KC_24     ┆ 24A          ┆ PDK2      ┆ 7.02      ┆ Kwong et al. │
# │ …         ┆ …            ┆ …         ┆ …         ┆ …            │
# │ YR_102005 ┆ 05420180C    ┆ LINC00458 ┆ 0.0       ┆ Yan et al.   │
# │ YR_2214   ┆ 05320205B    ┆ DDX55     ┆ 20.837138 ┆ Yan et al.   │
# │ YR_112016 ┆ 05420211C    ┆ HDHD5     ┆ 5.826272  ┆ Yan et al.   │
# │ HL_Shi-44 ┆ Pt6-baseline ┆ MIR6878   ┆ 0.0       ┆ Hugo et al.  │
# │ KC_9      ┆ 9A           ┆ DLG1-AS1  ┆ 0.02      ┆ Kwong et al. │
# └───────────┴──────────────┴───────────┴───────────┴──────────────┘

# %%
gex_matrix = gex_df.pivot(on='sample_id', index='HGNC', values='value')
gex_matrix
# Out:
# shape: (38_792, 96)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ HGNC      ┆ 05320459B ┆ 05320196B ┆ 05320234B ┆ … ┆ 05320220B ┆ 05420129C ┆ 05320302B ┆ 05320449 │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ B        │
# │ str       ┆ f64       ┆ f64       ┆ f64       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ CYP4F24P  ┆ 0.050866  ┆ 0.0       ┆ 0.029555  ┆ … ┆ 0.006098  ┆ 0.018093  ┆ 0.0       ┆ 0.0      │
# │ TEX11     ┆ 0.104033  ┆ 0.029169  ┆ 0.092995  ┆ … ┆ 0.047971  ┆ 0.014232  ┆ 0.094406  ┆ 3.296924 │
# │ TBC1D9B   ┆ 15.704316 ┆ 12.590393 ┆ 18.593042 ┆ … ┆ 11.47279  ┆ 15.541999 ┆ 10.972489 ┆ 11.65171 │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 5        │
# │ PMCHL2    ┆ 0.0       ┆ 0.031077  ┆ 0.059447  ┆ … ┆ 0.0       ┆ 0.0       ┆ 0.0       ┆ 0.0      │
# │ PDK2      ┆ 6.696817  ┆ 9.88272   ┆ 6.020661  ┆ … ┆ 10.573252 ┆ 12.858917 ┆ 7.174111  ┆ 8.492962 │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ LOC101928 ┆ null      ┆ null      ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 509       ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ LOC100129 ┆ null      ┆ null      ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 636       ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ MT-TQ     ┆ null      ┆ null      ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ OR11K2P   ┆ null      ┆ null      ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ IGHV1-69  ┆ null      ┆ null      ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
gex_matrix.write_csv('../dataset/created/gex_mat_rna_seq.csv')
